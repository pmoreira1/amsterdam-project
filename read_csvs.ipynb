# %%
import pandas as pd
containers = pd.read_csv('data/containers.csv')
container_types = pd.read_csv('data/container_types.csv')
wells = pd.read_csv('data/wells.csv')

# %%
# print((list(set(containers['address']))))
containers
# Out:
#     Unnamed: 0                 _display  \
# 0            0  Container object (3888)
# 1            1  Container object (3890)
# 2            2  Container object (4046)
# 3            3  Container object (4048)
# 4            4  Container object (4086)
# 5            5  Container object (4864)
# 6            6  Container object (4948)
# 7            7  Container object (4950)
# 8            8  Container object (4986)
# 9            9  Container object (4990)
# 10          10  Container object (4992)
# 11          11  Container object (6272)
# 12          12  Container object (7324)
# 13          13  Container object (7326)
# 14          14  Container object (7328)
# 15          15  Container object (7330)
# 16          16  Container object (7342)
# 17          17  Container object (7344)
# 18          18  Container object (7346)
# 19          19  Container object (7348)
#
#                                      _links.self.href  active  \
# 0   https://api.data.amsterdam.nl/afval/v1/contain...       1
# 1   https://api.data.amsterdam.nl/afval/v1/contain...       1
# 2   https://api.data.amsterdam.nl/afval/v1/contain...       1
# 3   https://api.data.amsterdam.nl/afval/v1/contain...       1
# 4   https://api.data.amsterdam.nl/afval/v1/contain...       1
# 5   https://api.data.amsterdam.nl/afval/v1/contain...       1
# 6   https://api.data.amsterdam.nl/afval/v1/contain...       1
# 7   https://api.data.amsterdam.nl/afval/v1/contain...       1
# 8   https://api.data.amsterdam.nl/afval/v1/contain...       0
# 9   https://api.data.amsterdam.nl/afval/v1/contain...       0
# 10  https://api.data.amsterdam.nl/afval/v1/contain...       0
# 11  https://api.data.amsterdam.nl/afval/v1/contain...       1
# 12  https://api.data.amsterdam.nl/afval/v1/contain...       1
# 13  https://api.data.amsterdam.nl/afval/v1/contain...       1
# 14  https://api.data.amsterdam.nl/afval/v1/contain...       1
# 15  https://api.data.amsterdam.nl/afval/v1/contain...       1
# 16  https://api.data.amsterdam.nl/afval/v1/contain...       1
# 17  https://api.data.amsterdam.nl/afval/v1/contain...       1
# 18  https://api.data.amsterdam.nl/afval/v1/contain...       1
# 19  https://api.data.amsterdam.nl/afval/v1/contain...       1
#
#                                     address  container_type.id  \
# 0           Reimerswaalstraat 22, Amsterdam                 27
# 1           Reimerswaalstraat 22, Amsterdam                138
# 2          Blankenbergestraat 14, Amsterdam               1994
# 3                Antwerpenbaan 8, Amsterdam                 27
# 4         Oudenaardeplantsoen 13, Amsterdam                 27
# 5                Senecastraat 32, Amsterdam                 27
# 6          Pieter Calandlaan 169, Amsterdam                 27
# 7          Pieter Calandlaan 169, Amsterdam                 27
# 8             Rijswijkstraat 175, Amsterdam                 27
# 9             Rijswijkstraat 175, Amsterdam                 27
# 10            Rijswijkstraat 175, Amsterdam               1994
# 11  Fogostraat 1, 1060 Amsterdam, Nederland                140
# 12             Veeteeltstraat 19, Amsterdam               3322
# 13               Sikkelstraat 21, Amsterdam                344
# 14                 Zuivelplein 9, Amsterdam                344
# 15                   Egstraat 37, Amsterdam               3322
# 16             Veeteeltstraat 19, Amsterdam               3323
# 17               Sikkelstraat 63, Amsterdam                333
# 18                 Zuivelplein 9, Amsterdam                333
# 19                   Egstraat 33, Amsterdam               3323
#
#                                   container_type.name  container_type.volume  \
# 0               Nieuw-West (SV)  Rest 5m3 TR Opl inst                    5.0
# 1                               Nieuw-West papier 5m3                    5.0
# 2                    5TV1423R G2 KH BEL PAP TROPL 4/6                    5.0
# 3               Nieuw-West (SV)  Rest 5m3 TR Opl inst                    5.0
# 4               Nieuw-West (SV)  Rest 5m3 TR Opl inst                    5.0
# 5               Nieuw-West (SV)  Rest 5m3 TR Opl inst                    5.0
# 6               Nieuw-West (SV)  Rest 5m3 TR Opl inst                    5.0
# 7               Nieuw-West (SV)  Rest 5m3 TR Opl inst                    5.0
# 8               Nieuw-West (SV)  Rest 5m3 TR Opl inst                    5.0
# 9               Nieuw-West (SV)  Rest 5m3 TR Opl inst                    5.0
# 10                   5TV1423R G2 KH BEL PAP TROPL 4/6                    5.0
# 11                                     Algemene order                    0.0
# 12  5m3 KHC Papier Amsterdam Standaard 1380*1380*2690                    5.0
# 13                     Oost stadsdeel KHDC papier 5M3                    5.0
# 14                     Oost stadsdeel KHDC papier 5M3                    5.0
# 15  5m3 KHC Papier Amsterdam Standaard 1380*1380*2690                    5.0
# 16    5m3 KHC Glas Amsterdam Standaard 1380*1380*2690                    5.0
# 17                     Oost stadsdeel KHDC Glas 1 4m3                    4.0
# 18                     Oost stadsdeel KHDC Glas 1 4m3                    4.0
# 19    5m3 KHC Glas Amsterdam Standaard 1380*1380*2690                    5.0
#
#     container_type.weight    id  ... well.geometrie.coordinates.0  \
# 0                     700  3888  ...                     4.793864
# 1                     650  3890  ...                     4.793854
# 2                     700  4046  ...                     4.801099
# 3                     700  4048  ...                     4.805253
# 4                     700  4086  ...                     4.801831
# 5                     700  4864  ...                     4.813301
# 6                     700  4948  ...                     4.815154
# 7                     700  4950  ...                     4.815125
# 8                     700  4986  ...                     4.838749
# 9                     700  4990  ...                     4.838750
# 10                    700  4992  ...                     4.838750
# 11                      0  6272  ...                     4.771005
# 12                    630  7324  ...                     4.947584
# 13                    600  7326  ...                     4.948291
# 14                    600  7328  ...                     4.946211
# 15                    630  7330  ...                     4.945066
# 16                    630  7342  ...                     4.947609
# 17                    500  7344  ...                     4.948267
# 18                    500  7346  ...                     4.946290
# 19                    630  7348  ...                     4.945095
#
#    well.geometrie.coordinates.1  well.geometrie.type  \
# 0                     52.363042                Point
# 1                     52.363060                Point
# 2                     52.346473                Point
# 3                     52.345334                Point
# 4                     52.347786                Point
# 5                     52.373639                Point
# 6                     52.355046                Point
# 7                     52.355040                Point
# 8                     52.349885                Point
# 9                     52.349904                Point
# 10                    52.349921                Point
# 11                    52.357027                Point
# 12                    52.341423                Point
# 13                    52.340347                Point
# 14                    52.339809                Point
# 15                    52.343121                Point
# 16                    52.341436                Point
# 17                    52.340249                Point
# 18                    52.339832                Point
# 19                    52.343120                Point
#
#    well.geometrie_rd.coordinates.0 well.geometrie_rd.coordinates.1  \
# 0                    114584.795600                   486293.453202
# 1                    114584.131408                   486295.528253
# 2                    115062.710016                   484445.966384
# 3                    115344.769279                   484316.924881
# 4                    115113.747415                   484591.672412
# 5                    115918.085415                   487461.893867
# 6                    116027.927365                   485392.219343
# 7                    116025.932817                   485391.567473
# 8                    117631.043485                   484805.569338
# 9                    117631.106838                   484807.638453
# 10                   117631.121404                   484809.563288
# 11                   113022.125574                   485637.240004
# 12                   125040.686038                   483813.467396
# 13                   125088.197626                   483693.460639
# 14                   124946.079367                   483634.424668
# 15                   124870.270886                   484003.421021
# 16                   125042.453921                   483814.869762
# 17                   125086.486823                   483682.621856
# 18                   124951.487273                   483636.944539
# 19                   124872.280759                   484003.294808
#
#    well.geometrie_rd.type well.id    well.id_number well.serial_number  \
# 0                   Point    3887        WLREF31196             554143
# 1                   Point    3889        WLPAF32018           WL661844
# 2                   Point    4045        WLPAF60317         WLPAF60317
# 3                   Point    4047          REF60325           REF60325
# 4                   Point    4085        WLREF60725         WLREF60725
# 5                   Point   27488         WLSR31448       BANWS02469WL
# 6                   Point    4947        WLREF31420              62195
# 7                   Point    4949        WLREF31419              53718
# 8                   Point   74272        WLREF31049         WLREF60778
# 9                   Point   26677        WLREF31050       BANWS01658WL
# 10                  Point   26676        WLPAF32049       BANWS01657WL
# 11                  Point    6271  WLAlgemene order   WLAlgemene order
# 12                  Point    7323        PA M 60067         WLPAM60067
# 13                  Point    7325          PAM60065         WLPAM60065
# 14                  Point    7327        WLPAM60071         WLPAM60071
# 15                  Point    7329        PA M 60061         WLPAM60061
# 16                  Point    7341        GL M 70045         WLGLM70045
# 17                  Point    7343          GLM70044         WLGLM70044
# 18                  Point    7345        WLGLM70049         WLGLM70049
# 19                  Point    7347        GL M 70041         WLGLM70041
#
#              well.site
# 0   114585-486293-F82a
# 1   114585-486293-F82a
# 2   115063-484448-F88e
# 3   115345-484317-F88e
# 4   115115-484595-F88e
# 5   115918-487462-F77f
# 6   116027-485392-F81e
# 7   116027-485392-F81e
# 8   117631-484808-F87d
# 9   117631-484808-F87d
# 10  117631-484808-F87d
# 11                 NaN
# 12  125042-483814-M57a
# 13  125087-483688-M57a
# 14  124949-483636-M57a
# 15  124871-484003-M57a
# 16  125042-483814-M57a
# 17  125087-483688-M57a
# 18  124949-483636-M57a
# 19  124871-484003-M57a
#
# [20 rows x 29 columns]

# %%
container_types
# Out:
#     container_type_id                                        name  volume  \
# 0                   9                                HMS rest 5M3     5.0
# 1                  27       Nieuw-West (SV)  Rest 5m3 TR Opl inst     5.0
# 2                  41                           Nieuw west Papier     4.0
# 3                  48                         Nieuw west rest 5m3     5.0
# 4                  59                           Bovengrondse Glas     3.0
# 5                 109        nieuw-West Glas 1 4m3 KH TR OPL inst     4.0
# 6                 138                       Nieuw-West papier 5m3     5.0
# 7                 139                  Nieuw-west rest 5m3 Rubens     5.0
# 8                 140                              Algemene order     0.0
# 9                 149  Oost stadsdeel ijburg Rubens KH Glas 1 5m3     5.0
# 10                160             Centrum Stadsdeel Glas 1 KH 3m3     3.0
# 11                206         Oost Stadsdeel Ijburg papier KH 5m3     5.0
# 12                210                  centrum Stadsdeel Glas 3m3     3.0
# 13                214             Nieuwe west  3m3 belfast glas 1     3.0
# 14                215             Nieuw west  3m3 belfast papier      3.0
# 15                216               Nieuwe west  3m3 belfast rest     3.0
# 16                244               Nieuw West rest  belfast 5m3      5.0
# 17                298                                Kikker Rest      3.0
# 18                320              Centrum amsterdam EVO Glas 4m3     4.0
# 19                321         Centrum Amsterdam EVO papier KH 4m3     4.0
#
#     weight
# 0      500
# 1      700
# 2      650
# 3      700
# 4      350
# 5      600
# 6      650
# 7      650
# 8        0
# 9      600
# 10     500
# 11     600
# 12     500
# 13     500
# 14     500
# 15     550
# 16     700
# 17     350
# 18     600
# 19     600

# %%
wells
# Out:
#     well_id stadsdeel buurt_code geometrie.type         address.neighbourhood  \
# 0      2829         F       F86a          Point   86a - Overtoomse Veld Noord
# 1      3235         F       F86b          Point    86b - Overtoomse Veld Zuid
# 2      3493         F       F85a          Point    85a - Oostoever Sloterplas
# 3      3559         F       F85a          Point    85a - Oostoever Sloterplas
# 4      3565         F       F85a          Point    85a - Oostoever Sloterplas
# 5      3567         F       F85a          Point    85a - Oostoever Sloterplas
# 6      3887         F       F82a          Point     82a - Osdorp Midden Noord
# 7      3889         F       F82a          Point     82a - Osdorp Midden Noord
# 8      3949         F       F88e          Point  88e - Nieuw Sloten Noordwest
# 9      4021         F       F88h          Point   88h - Nieuw Sloten Zuidwest
# 10     4045         F       F88e          Point  88e - Nieuw Sloten Noordwest
# 11     4047         F       F88e          Point  88e - Nieuw Sloten Noordwest
# 12     4051         F       F85a          Point    85a - Oostoever Sloterplas
# 13     4085         F       F88e          Point  88e - Nieuw Sloten Noordwest
# 14     4739         F       F89a          Point    89a - Louis Chrispijnbuurt
#
#                                       address.summary
# 0                   Jan Evertsenstraat 717, Amsterdam
# 1                     Derkinderenstraat 11, Amsterdam
# 2                            Uffizilaan 11, Amsterdam
# 3                        Guggenheimlaan 59, Amsterdam
# 4                          Mezquitalaan 43, Amsterdam
# 5                          Mezquitalaan 43, Amsterdam
# 6                     Reimerswaalstraat 22, Amsterdam
# 7                     Reimerswaalstraat 22, Amsterdam
# 8                   Oudenaardeplantsoen 83, Amsterdam
# 9   Schaarbeekstraat 34, Amsterdam / Liederkerkepl...
# 10                   Blankenbergestraat 14, Amsterdam
# 11                         Antwerpenbaan 8, Amsterdam
# 12                       Tretjakovlaan 122, Amsterdam
# 13                  Oudenaardeplantsoen 13, Amsterdam
# 14                    Tourniairestraat 106, Amsterdam
